# %% [markdown]
# # Seismic detection using neural network with CNN and LSTM layers combined

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import csv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout, Input, LSTM, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## Processing functions

# %%
# Load seismic data from the CSV file
def load_seismic_data(file_path):
    data = pd.read_csv(file_path)
    return data

# Preprocess the velocity data
def preprocess_data(velocity_data):
    # 1. Normalize the velocity data (zero mean, unit variance)
    normalized_data = (velocity_data - np.mean(velocity_data)) / np.std(velocity_data)
    
    # 2. Reshape to add the feature dimension (required by Conv1D)
    reshaped_data = np.expand_dims(normalized_data, axis=-1)  # Shape: (timesteps, 1 feature)
    
    return reshaped_data

# %%
# Load seismic data from the CSV file
def load_seismic_data(file_path):
    data = pd.read_csv(file_path)
    return data

# Preprocess the velocity data
def preprocess_data(velocity_data):
    # 1. Normalize the velocity data (zero mean, unit variance)
    normalized_data = (velocity_data - np.mean(velocity_data)) / np.std(velocity_data)
    
    # 2. Reshape to add the feature dimension (required by Conv1D)
    reshaped_data = np.expand_dims(normalized_data, axis=-1)  # Shape: (timesteps, 1 feature)
    
    return reshaped_data

# %% [markdown]
# ## Model arcitecture

# %%
# Model architecture: 1D Convolutional Neural Network with LSTM
def build_complex_model(input_shape):
    model = Sequential()
    
    # Input layer
    model.add(Input(shape=input_shape))
    
    # First Conv1D layer
    model.add(Conv1D(64, kernel_size=5, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    
    # Second Conv1D layer
    model.add(Conv1D(128, kernel_size=5, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # Using LSTM for sequence learning
    model.add(LSTM(128, return_sequences=False))

    # Dense and output layers
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5)) # Dropout to prevent overfitting
    model.add(Dense(1))  # Output the predicted (normalized) index
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    
    return model

# %% [markdown]
# ## Load the data and preprocess for training

# %%
# Load and process the catalog
cat_directory = './data/lunar/training/catalogs/'
cat_file = cat_directory + 'apollo12_catalog_GradeA_final.csv'
cat = pd.read_csv(cat_file)

# Prepare training data (seismic data + labels for quake start detection)
X_train = []
y_train = []

# Define a max length for padding/truncating
MAX_TIMESTEPS = 60000  # the maximum expected length of the recording

# Loop through the catalog
for i, (file_name, _, start_time, _, quake_type) in cat.iterrows():
    file_path = f"./data/lunar/training/data/S12_GradeA/{file_name}.csv"
    # Check if file exists
    if not os.path.isfile(file_path):
        continue

    # Load seismic data
    data_chunk = load_seismic_data(file_path)
    velocity = data_chunk['velocity(m/s)'].values
    time = data_chunk['time_rel(sec)'].values

    # Preprocess velocity data
    processed_velocity = preprocess_data(velocity)  # Shape: (timesteps, 1 feature)

    # Labeling: Create a label with the exact time index of the quake start
    start_index = np.argmin(np.abs(time - start_time))  # Closest index to the start time
    
    # Append processed data and the start index to the training set
    X_train.append(processed_velocity)
    y_train.append(start_index)  # The label is the index of the quake start

# Convert lists to numpy arrays with consistent time series length using padding
X_train_padded = pad_sequences(X_train, maxlen=MAX_TIMESTEPS, dtype='float32', padding='post', truncating='post')

# Convert lists to numpy arrays for model training
X_train = np.array(X_train_padded)
y_train = np.array(y_train)  # The labels are now the start indices

# Check the shape of X_train and y_train
print("X_train shape:", X_train.shape)  # Should be (samples, timesteps, 1)
print("y_train shape:", y_train.shape)  # Should be (samples,)

# Split data into train and test sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

#normalize to 0-1
y_train = y_train / MAX_TIMESTEPS  # MAX_TIMESTEPS is 60000 or the max length of the sequence
y_val = y_val / MAX_TIMESTEPS

# Build the model
# Build the updated model
input_shape = (X_train.shape[1], X_train.shape[2])
model = build_complex_model(input_shape)
# Out:
# X_train shape: (75, 60000, 1)
# y_train shape: (75,)
# 2024-10-06 10:20:07.268299: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2024-10-06 10:20:07.268355: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-10-06 10:20:07.268368: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-10-06 10:20:07.268398: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-06 10:20:07.268426: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Train the model

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 8.7404 - mae: 2.5134 - val_loss: 4.7057 - val_mae: 1.8509
# Epoch 2/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.1549 - mae: 2.2718 - val_loss: 4.7871 - val_mae: 1.8689
# Epoch 3/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.5668 - mae: 2.3771 - val_loss: 4.8293 - val_mae: 1.8771
# Epoch 4/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 8.3887 - mae: 2.4669 - val_loss: 4.8902 - val_mae: 1.8833
# Epoch 5/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 8.0587 - mae: 2.5374 - val_loss: 4.8141 - val_mae: 1.8712
# Epoch 6/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 8.5159 - mae: 2.4860 - val_loss: 4.6624 - val_mae: 1.8498
# Epoch 7/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.6727 - mae: 2.3812 - val_loss: 4.5428 - val_mae: 1.8602
# Epoch 8/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 7.1789 - mae: 2.2851 - val_loss: 4.4176 - val_mae: 1.8543
# Epoch 9/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.0785 - mae: 2.2583 - val_loss: 4.3654 - val_mae: 1.8564
# Epoch 10/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.7188 - mae: 2.2519 - val_loss: 4.3604 - val_mae: 1.8470
# Epoch 11/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.7571 - mae: 2.2058 - val_loss: 4.3757 - val_mae: 1.8370
# Epoch 12/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.5039 - mae: 2.3702 - val_loss: 4.4944 - val_mae: 1.8566
# Epoch 13/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.8450 - mae: 2.4564 - val_loss: 4.5106 - val_mae: 1.8725
# Epoch 14/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 5.8728 - mae: 2.0419 - val_loss: 4.5438 - val_mae: 1.8959
# Epoch 15/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.9380 - mae: 2.2600 - val_loss: 4.4417 - val_mae: 1.8813
# Epoch 16/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.5964 - mae: 2.2115 - val_loss: 4.3381 - val_mae: 1.8614
# Epoch 17/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.7824 - mae: 2.2756 - val_loss: 4.2545 - val_mae: 1.8473
# Epoch 18/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.4518 - mae: 2.4080 - val_loss: 4.2088 - val_mae: 1.8424
# Epoch 19/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.2867 - mae: 2.0541 - val_loss: 4.4372 - val_mae: 1.8878
# Epoch 20/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 5.8507 - mae: 2.0688 - val_loss: 4.4926 - val_mae: 1.8838
# Epoch 21/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.7286 - mae: 2.3881 - val_loss: 4.6149 - val_mae: 1.8818
# Epoch 22/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.5977 - mae: 2.1471 - val_loss: 4.6373 - val_mae: 1.8615
# Epoch 23/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.3242 - mae: 2.2100 - val_loss: 4.6178 - val_mae: 1.9026
# Epoch 24/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.2612 - mae: 2.0807 - val_loss: 4.8201 - val_mae: 1.9326
# Epoch 25/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 7.3191 - mae: 2.2627 - val_loss: 4.7365 - val_mae: 1.9136
# Epoch 26/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.6913 - mae: 2.1776 - val_loss: 4.4543 - val_mae: 1.8527
# Epoch 27/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.6962 - mae: 2.1160 - val_loss: 4.3674 - val_mae: 1.8244
# Epoch 28/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.7416 - mae: 2.1407 - val_loss: 4.5231 - val_mae: 1.8463
# Epoch 29/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 5.8506 - mae: 2.0410 - val_loss: 4.8907 - val_mae: 1.9306
# Epoch 30/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 6.1850 - mae: 2.1607 - val_loss: 4.5887 - val_mae: 1.8315

# %% [markdown]
# ## Model evaluation

# %%
# Evaluate the model
loss, mae = model.evaluate(X_val, y_val)
print(f"Validation MAE: {mae:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - loss: 4.5887 - mae: 1.8315
# Validation MAE: 1.8315

# %% [markdown]
# ## Predictions for the test dataset

# %% [markdown]
# The code outputs prediction to both CSV files (that can be used later to score the model), and images, which provides the ability to visually assess the model

# %%
# Define the directory for test files
test_directory = "./data/lunar/test/data/S12_GradeB/"
output_plot_dir = "./predictions_plots_v1/"  # Directory to save plots
output_csv_file = "./predictions_output_v1.csv"  # CSV file to save the predictions

# Ensure output directory exists
os.makedirs(output_plot_dir, exist_ok=True)

# Function to predict moonquake start, save plot, and store results in a CSV
def predict_and_plot_for_all_files(model, test_directory, max_timesteps=60000):
    predictions = []  # Store the results here
    
    # Open CSV file for writing
    with open(output_csv_file, mode='w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write the header for the CSV file
        csv_writer.writerow(["filename", "time_rel(sec)"])
        
        # Iterate through all the CSV files in the test directory
        for file_name in os.listdir(test_directory):
            if file_name.endswith(".csv"):  # Only process CSV files
                file_path = os.path.join(test_directory, file_name)
                print(f"Processing file: {file_name}")  # For debugging/logging
                
                # Load seismic data from the file
                data_chunk = load_seismic_data(file_path)
                velocity = data_chunk['velocity(m/s)'].values
                time = data_chunk['time_rel(sec)'].values
                
                # Preprocess the velocity data
                processed_velocity = preprocess_data(velocity)
                processed_velocity = pad_sequences([processed_velocity], maxlen=max_timesteps, dtype='float32', padding='post', truncating='post')

                # Make prediction
                predicted_index = model.predict(processed_velocity)
                predicted_index = int(predicted_index[0] * MAX_TIMESTEPS)  # Scale back to original range
                
                # Get the predicted start time using the index
                predicted_start_time = time[predicted_index]

                # Plotting the seismic data and the predicted moonquake start
                plt.figure(figsize=(10, 6))
                plt.plot(time, velocity, label="Seismic Velocity Data", color='blue')
                
                # Add a red line for the predicted quake start time
                plt.axvline(x=predicted_start_time, color='red', linestyle='--', label=f"Predicted Quake Start: {predicted_start_time:.2f}s")
                
                plt.title(f"Moonquake Prediction for {file_name}")
                plt.xlabel("Time (seconds)")
                plt.ylabel("Velocity (m/s)")
                plt.legend()
                
                # Save the plot to a file
                plot_filename = os.path.join(output_plot_dir, f"{file_name}_prediction_plot.png")
                plt.savefig(plot_filename)
                plt.close()  # Close the plot to avoid displaying it during processing

                # Store the result (file_name, predicted_start_time) in the CSV
                csv_writer.writerow([file_name, predicted_start_time])

                # Append the result to the predictions list for further use if needed
                predictions.append((file_name, predicted_start_time))
    
    return predictions

# Example usage
predictions = predict_and_plot_for_all_files(model, test_directory)

# Output the predictions
for file_name, predicted_start_time in predictions:
    print(f"File: {file_name}, Predicted Moonquake Start Time: {predicted_start_time}")
# Out:
# Processing file: xa.s12.00.mhz.1970-05-23HR00_evid00027.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Processing file: xa.s12.00.mhz.1977-04-11HR00_evid00915.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing file: xa.s12.00.mhz.1970-07-18HR00_evid00036.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1971-11-24HR00_evid00156.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1972-12-06HR00_evid00342.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1974-03-14HR00_evid00506.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1973-11-22HR00_evid00475.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing file: xa.s12.00.mhz.1971-04-08HR01_evid00083.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1973-10-10HR00_evid00463.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1974-07-25HR05_evid00553.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1972-02-21HR00_evid00190.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1974-05-09HR00_evid00522.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1970-10-26HR00_evid00049.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1972-12-02HR00_evid00341.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1972-11-14HR00_evid00331.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Processing file: xa.s12.00.mhz.1972-12-15HR00_evid00349.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1970-06-19HR00_evid00031.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1971-06-11HR00_evid00096.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1970-07-27HR00_evid00039.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1970-03-30HR00_evid00020.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1970-11-03HR00_evid00051.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1974-06-30HR00_evid00543.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1970-11-03HR00_evid00050.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1971-01-17HR00_evid00060.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1971-01-03HR00_evid00057.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing file: xa.s12.00.mhz.1969-12-16HR00_evid00006.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1971-10-26HR00_evid00133.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1970-05-20HR00_evid00026.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1975-04-21HR00_evid00638.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1973-03-12HR00_evid00384.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1970-07-17HR00_evid00035.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Processing file: xa.s12.00.mhz.1973-10-03HR03_evid00461.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1970-03-14HR00_evid00018.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1975-05-20HR00_evid00652.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1977-07-19HR00_evid00991.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing file: xa.s12.00.mhz.1972-01-26HR00_evid00186.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1971-03-15HR00_evid00073.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Processing file: xa.s12.00.mhz.1977-04-26HR00_evid00924.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1970-05-25HR00_evid00029.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1972-05-19HR00_evid00228.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1973-08-08HR00_evid00437.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Processing file: xa.s12.00.mhz.1970-04-03HR00_evid00021.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1970-02-07HR00_evid00014.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1971-10-06HR00_evid00124.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1972-05-15HR00_evid00223.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Processing file: xa.s12.00.mhz.1971-10-06HR00_evid00125.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1975-06-15HR00_evid00660.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1970-05-24HR00_evid00028.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1974-10-02HR00_evid00572.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1972-11-19HR00_evid00335.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1971-01-05HR00_evid00059.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1972-02-28HR00_evid00192.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1970-09-09HR00_evid00043.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1971-06-27HR00_evid00101.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1971-05-22HR00_evid00092.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1975-05-16HR00_evid00651.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1970-02-18HR00_evid00016.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing file: xa.s12.00.mhz.1970-01-09HR00_evid00007.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing file: xa.s12.00.mhz.1977-09-13HR00_evid01012.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing file: xa.s12.00.mhz.1975-06-17HR00_evid00662.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1970-07-20HR00_evid00037.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Processing file: xa.s12.00.mhz.1977-04-24HR00_evid00923.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing file: xa.s12.00.mhz.1974-03-30HR00_evid00512.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing file: xa.s12.00.mhz.1973-04-23HR00_evid00399.csv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# File: xa.s12.00.mhz.1970-05-23HR00_evid00027.csv, Predicted Moonquake Start Time: 17273.509433962263
# File: xa.s12.00.mhz.1977-04-11HR00_evid00915.csv, Predicted Moonquake Start Time: 39782.03773584906
# File: xa.s12.00.mhz.1970-07-18HR00_evid00036.csv, Predicted Moonquake Start Time: 44924.67924528302
# File: xa.s12.00.mhz.1971-11-24HR00_evid00156.csv, Predicted Moonquake Start Time: 46199.698113207545
# File: xa.s12.00.mhz.1972-12-06HR00_evid00342.csv, Predicted Moonquake Start Time: 59456.45283018868
# File: xa.s12.00.mhz.1974-03-14HR00_evid00506.csv, Predicted Moonquake Start Time: 43248.301886792455
# File: xa.s12.00.mhz.1973-11-22HR00_evid00475.csv, Predicted Moonquake Start Time: 45072.45283018868
# File: xa.s12.00.mhz.1971-04-08HR01_evid00083.csv, Predicted Moonquake Start Time: 34304.301886792455
# File: xa.s12.00.mhz.1973-10-10HR00_evid00463.csv, Predicted Moonquake Start Time: 66019.01886792453
# File: xa.s12.00.mhz.1974-07-25HR05_evid00553.csv, Predicted Moonquake Start Time: 27514.716981132075
# File: xa.s12.00.mhz.1972-02-21HR00_evid00190.csv, Predicted Moonquake Start Time: 45081.660377358494
# File: xa.s12.00.mhz.1974-05-09HR00_evid00522.csv, Predicted Moonquake Start Time: 60142.03773584906
# File: xa.s12.00.mhz.1970-10-26HR00_evid00049.csv, Predicted Moonquake Start Time: 57928.301886792455
# File: xa.s12.00.mhz.1972-12-02HR00_evid00341.csv, Predicted Moonquake Start Time: 39068.981132075474
# File: xa.s12.00.mhz.1972-11-14HR00_evid00331.csv, Predicted Moonquake Start Time: 29162.264150943396
# File: xa.s12.00.mhz.1972-12-15HR00_evid00349.csv, Predicted Moonquake Start Time: 48071.09433962264
# File: xa.s12.00.mhz.1970-06-19HR00_evid00031.csv, Predicted Moonquake Start Time: 45225.50943396227
# File: xa.s12.00.mhz.1971-06-11HR00_evid00096.csv, Predicted Moonquake Start Time: 45112.75471698113
# File: xa.s12.00.mhz.1970-07-27HR00_evid00039.csv, Predicted Moonquake Start Time: 45197.28301886792
# File: xa.s12.00.mhz.1970-03-30HR00_evid00020.csv, Predicted Moonquake Start Time: 24200.30188679245
# File: xa.s12.00.mhz.1970-11-03HR00_evid00051.csv, Predicted Moonquake Start Time: 31524.22641509434
# File: xa.s12.00.mhz.1974-06-30HR00_evid00543.csv, Predicted Moonquake Start Time: 43359.84905660377
# File: xa.s12.00.mhz.1970-11-03HR00_evid00050.csv, Predicted Moonquake Start Time: 31524.22641509434
# File: xa.s12.00.mhz.1971-01-17HR00_evid00060.csv, Predicted Moonquake Start Time: 45043.32075471698
# File: xa.s12.00.mhz.1971-01-03HR00_evid00057.csv, Predicted Moonquake Start Time: 28797.283018867925
# File: xa.s12.00.mhz.1969-12-16HR00_evid00006.csv, Predicted Moonquake Start Time: 45033.96226415094
# File: xa.s12.00.mhz.1971-10-26HR00_evid00133.csv, Predicted Moonquake Start Time: 49416.75471698113
# File: xa.s12.00.mhz.1970-05-20HR00_evid00026.csv, Predicted Moonquake Start Time: 45035.018867924526
# File: xa.s12.00.mhz.1975-04-21HR00_evid00638.csv, Predicted Moonquake Start Time: 51186.41509433962
# File: xa.s12.00.mhz.1973-03-12HR00_evid00384.csv, Predicted Moonquake Start Time: 21811.169811320753
# File: xa.s12.00.mhz.1970-07-17HR00_evid00035.csv, Predicted Moonquake Start Time: 31607.396226415098
# File: xa.s12.00.mhz.1973-10-03HR03_evid00461.csv, Predicted Moonquake Start Time: 38239.54716981132
# File: xa.s12.00.mhz.1970-03-14HR00_evid00018.csv, Predicted Moonquake Start Time: 25593.81132075472
# File: xa.s12.00.mhz.1975-05-20HR00_evid00652.csv, Predicted Moonquake Start Time: 40000.90566037736
# File: xa.s12.00.mhz.1977-07-19HR00_evid00991.csv, Predicted Moonquake Start Time: 31961.66037735849
# File: xa.s12.00.mhz.1972-01-26HR00_evid00186.csv, Predicted Moonquake Start Time: 28043.77358490566
# File: xa.s12.00.mhz.1971-03-15HR00_evid00073.csv, Predicted Moonquake Start Time: 55266.41509433962
# File: xa.s12.00.mhz.1977-04-26HR00_evid00924.csv, Predicted Moonquake Start Time: 26214.64150943396
# File: xa.s12.00.mhz.1970-05-25HR00_evid00029.csv, Predicted Moonquake Start Time: 54767.3962264151
# File: xa.s12.00.mhz.1972-05-19HR00_evid00228.csv, Predicted Moonquake Start Time: 10633.962264150943
# File: xa.s12.00.mhz.1973-08-08HR00_evid00437.csv, Predicted Moonquake Start Time: 56749.88679245283
# File: xa.s12.00.mhz.1970-04-03HR00_evid00021.csv, Predicted Moonquake Start Time: 39534.64150943396
# File: xa.s12.00.mhz.1970-02-07HR00_evid00014.csv, Predicted Moonquake Start Time: 49990.188679245286
# File: xa.s12.00.mhz.1971-10-06HR00_evid00124.csv, Predicted Moonquake Start Time: 14848.90566037736
# File: xa.s12.00.mhz.1972-05-15HR00_evid00223.csv, Predicted Moonquake Start Time: 50710.79245283019
# File: xa.s12.00.mhz.1971-10-06HR00_evid00125.csv, Predicted Moonquake Start Time: 14848.90566037736
# File: xa.s12.00.mhz.1975-06-15HR00_evid00660.csv, Predicted Moonquake Start Time: 45034.56603773585
# File: xa.s12.00.mhz.1970-05-24HR00_evid00028.csv, Predicted Moonquake Start Time: 21132.22641509434
# File: xa.s12.00.mhz.1974-10-02HR00_evid00572.csv, Predicted Moonquake Start Time: 45046.188679245286
# File: xa.s12.00.mhz.1972-11-19HR00_evid00335.csv, Predicted Moonquake Start Time: 45375.84905660377
# File: xa.s12.00.mhz.1971-01-05HR00_evid00059.csv, Predicted Moonquake Start Time: 44050.71698113208
# File: xa.s12.00.mhz.1972-02-28HR00_evid00192.csv, Predicted Moonquake Start Time: 29728.150943396227
# File: xa.s12.00.mhz.1970-09-09HR00_evid00043.csv, Predicted Moonquake Start Time: 50288.6037735849
# File: xa.s12.00.mhz.1971-06-27HR00_evid00101.csv, Predicted Moonquake Start Time: 38480.75471698113
# File: xa.s12.00.mhz.1971-05-22HR00_evid00092.csv, Predicted Moonquake Start Time: 53671.698113207545
# File: xa.s12.00.mhz.1975-05-16HR00_evid00651.csv, Predicted Moonquake Start Time: 30357.88679245283
# File: xa.s12.00.mhz.1970-02-18HR00_evid00016.csv, Predicted Moonquake Start Time: 43562.8679245283
# File: xa.s12.00.mhz.1970-01-09HR00_evid00007.csv, Predicted Moonquake Start Time: 13206.33962264151
# File: xa.s12.00.mhz.1977-09-13HR00_evid01012.csv, Predicted Moonquake Start Time: 43726.79245283019
# File: xa.s12.00.mhz.1975-06-17HR00_evid00662.csv, Predicted Moonquake Start Time: 50459.92452830189
# File: xa.s12.00.mhz.1970-07-20HR00_evid00037.csv, Predicted Moonquake Start Time: 38017.35849056604
# File: xa.s12.00.mhz.1977-04-24HR00_evid00923.csv, Predicted Moonquake Start Time: 46420.67924528302
# File: xa.s12.00.mhz.1974-03-30HR00_evid00512.csv, Predicted Moonquake Start Time: 63994.41509433962
# File: xa.s12.00.mhz.1973-04-23HR00_evid00399.csv, Predicted Moonquake Start Time: 43238.49056603773
