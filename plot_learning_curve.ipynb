# %%
import matplotlib.pyplot as plt

# Data extracted from the output
epochs = list(range(1, 31))
train_loss = [8.1913, 8.3567, 8.0280, 8.9551, 7.7815, 7.2905, 7.9147, 7.1787, 7.6946, 7.0228, 
              7.8049, 7.2922, 7.2575, 7.0526, 6.6588, 6.3269, 6.9893, 6.9150, 5.8245, 6.1949, 
              5.6490, 5.8030, 6.3082, 5.6573, 5.9936, 5.3687, 5.2072, 6.2130, 5.4830, 5.1658 ]
val_loss = [4.7614, 4.7222, 4.6695, 4.6282, 4.5892, 4.5430, 4.5122, 4.5237, 4.6423, 4.7810, 
            4.7036, 4.4497, 4.5066, 4.6312, 4.7088, 4.6828, 4.4993, 4.5028, 4.5766, 4.5827, 
            4.5572, 4.6494, 4.6587, 4.4491, 4.4906, 4.8858, 5.1670, 5.2484, 5.2161, 4.6932]

# Plot the learning curves
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')

plt.title('Learning Curve (Loss)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
